# %%
import pandas as pd

# %%
xlsx = pd.ExcelFile('./Apple_Tweets.xlsx')

Summary = pd.read_excel(xlsx, 'Summary')
Stream = pd.read_excel(xlsx, 'Stream')

Top_Users_Followers = pd.read_excel(xlsx, 'Top Users (Followers)')
Top_Users_Following = pd.read_excel(xlsx, 'Top Users (Following)')
Geolocalization = pd.read_excel(xlsx, 'Geolocalization')
Country_List = pd.read_excel(xlsx, 'Country List')

# %%
Stream
# Out:
#                   Tweet Id        Date   Hour            User Name  \
# 0       743056393796739072  2016-06-15  12:23                Sufiy
# 1       743055905214889984  2016-06-15  12:21        Breaking News
# 2       743055905193857024  2016-06-15  12:21         Hotpage News
# 3       743055497725673472  2016-06-15  12:20                Danny
# 4       743055311909441536  2016-06-15  12:19               Jayson
# ...                    ...         ...    ...                  ...
# 166626  716328052892897280  2016-04-02  18:14               Daniel
# 166627  716327961641680898  2016-04-02  18:14        Computer News
# 166628  716327961641639937  2016-04-02  18:14      Peripheral News
# 166629  716326132476461058  2016-04-02  18:07       Baylee Pulliam
# 166630  716325850564702208  2016-04-02  18:06  Swing Trade Warrior
#
#               Nickname                                                Bio  \
# 0                Sufiy  #Investing as a way of life based on common se...
# ...

# %%
Top_Users_Followers
# Out:
#               User Name         Nickname  \
# 0      Reuters Top News          Reuters
# 1   Wall Street Journal              WSJ
# 2           MarketWatch      MarketWatch
# 3                  CNBC             CNBC
# 4            Phil Davis   philstockworld
# ..                  ...              ...
# 95            FOREX.com         FOREXcom
# 96        Jesse Colombo  TheBubbleBubble
# 97                   KP      YoBigBrotha
# 98     Advice On Stocks    advice_stocks
# 99     Christina Warren        film_girl
#
#                                           Bio content  Followers  Following  \
# 0   Top and breaking news, pictures, and videos fr...   12871312       1044
# 1   Breaking news and features from the WSJ. Tweet...   11029379       1064
# 2   News, personal finance & commentary from Marke...    2860791        171
# 3                         First in Business Worldwide    2343352        969
# 4   Don't gamble with your investments! BE THE HOU...    1684856        268
# ...
